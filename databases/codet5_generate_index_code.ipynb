# %%
# !pip install pydantic-settings
# Out:
# Collecting pydantic-settings
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings) (2.9.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (4.12.2)
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, pydantic-settings
# Successfully installed pydantic-settings-2.6.1 python-dotenv-1.0.1

# %%
pip install chromadb==0.3.21
# Out:
# Collecting chromadb==0.3.21
#   Downloading chromadb-0.3.21-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (2.2.2)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (2.9.2)
# Collecting hnswlib>=0.7 (from chromadb==0.3.21)
#   Downloading hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clickhouse-connect>=0.5.7 (from chromadb==0.3.21)
#   Downloading clickhouse_connect-0.8.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: sentence-transformers>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (3.2.1)
# Requirement already satisfied: duckdb>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.1.3)
# Collecting fastapi>=0.85.1 (from chromadb==0.3.21)
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.3.21) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb==0.3.21)
#   Downloading posthog-3.7.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2024.8.30)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2.2.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from clickhouse-connect>=0.5.7->chromadb==0.3.21) (2024.2)
# Collecting zstandard (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting lz4 (from clickhouse-connect>=0.5.7->chromadb==0.3.21)
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.85.1->chromadb==0.3.21)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.85.1->chromadb==0.3.21) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->chromadb==0.3.21) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->chromadb==0.3.21) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.3.21) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb==0.3.21)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.3.21) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb==0.3.21) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.3.21) (3.10)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (4.46.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->chromadb==0.3.21) (11.0.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.3.21) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.3.21) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.3.21) (6.0.2)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb==0.3.21)
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (24.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi>=0.85.1->chromadb==0.3.21) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb==0.3.21) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.85.1->chromadb==0.3.21) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi>=0.85.1->chromadb==0.3.21) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.2.2->chromadb==0.3.21) (3.0.2)
# Downloading chromadb-0.3.21-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 4.1 MB/s eta 0:00:00
# Downloading clickhouse_connect-0.8.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.4/978.4 kB 45.1 MB/s eta 0:00:00
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.2 MB/s eta 0:00:00
# Downloading posthog-3.7.2-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.8 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.4 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 32.1 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.9 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 81.5 MB/s eta 0:00:00
# Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 33.4 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 14.4 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.3 MB/s eta 0:00:00
# Downloading zstandard-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 93.6 MB/s eta 0:00:00
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp310-cp310-linux_x86_64.whl size=2360794 sha256=4caeb48d45943dba07fcb8acff2423276355c12591a55987d28a6c84f42321ba
#   Stored in directory: /root/.cache/pip/wheels/af/a9/3e/3e5d59ee41664eb31a4e6de67d1846f86d16d93c45f277c4e7
# Successfully built hnswlib
# Installing collected packages: monotonic, zstandard, websockets, uvloop, uvicorn, lz4, httptools, hnswlib, backoff, watchfiles, starlette, posthog, clickhouse-connect, fastapi, chromadb
# Successfully installed backoff-2.2.1 chromadb-0.3.21 clickhouse-connect-0.8.7 fastapi-0.115.5 hnswlib-0.8.0 httptools-0.6.4 lz4-4.3.3 monotonic-1.6 posthog-3.7.2 starlette-0.41.3 uvicorn-0.32.1 uvloop-0.21.0 watchfiles-1.0.0 websockets-14.1 zstandard-0.23.0

# %%
# !pip install pydantic-settings
# !pip install --upgrade chromadb
# Out:
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings) (2.9.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings) (1.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->pydantic-settings) (4.12.2)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.3.21)
# Collecting chromadb
#   Downloading chromadb-0.5.20-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.115.5)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.32.1)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.28.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.6)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.68.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.13.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.1.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Collecting opentelemetry-util-http==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-0.5.20-py3-none-any.whl (617 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.9/617.9 kB 33.9 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.6 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 11.2 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 38.3 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.1 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 35.8 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.6 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 19.6 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.8 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=8107bebde2bdcf4a7ae45e1846c8158237cb6fe367ca3e94af2ecd95675478a8
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, durationpy, pyproject_hooks, protobuf, overrides, opentelemetry-util-http, mmh3, humanfriendly, chroma-hnswlib, bcrypt, asgiref, opentelemetry-proto, coloredlogs, build, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.3.21
#     Uninstalling chromadb-0.3.21:
#       Successfully uninstalled chromadb-0.3.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed asgiref-3.8.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.20 coloredlogs-15.0.1 durationpy-0.9 humanfriendly-10.0 kubernetes-31.0.0 mmh3-5.0.1 onnxruntime-1.20.1 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-instrumentation-0.49b2 opentelemetry-instrumentation-asgi-0.49b2 opentelemetry-instrumentation-fastapi-0.49b2 opentelemetry-proto-1.28.2 opentelemetry-util-http-0.49b2 overrides-7.7.0 protobuf-5.28.3 pypika-0.48.9 pyproject_hooks-1.2.0

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModel
from chromadb.config import Settings
from chromadb import Client
model_name = "Salesforce/codet5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)


csv_file = "/content/final_C++_dataset.csv"
df = pd.read_csv(csv_file)
codes = df['code'].to_list()
ids = df['task_id'].to_list()

# %%
def generate_embedding(code):
    inputs = tokenizer(code, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        # Use only the encoder to generate embeddings
        encoder_outputs = model.encoder(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"]
        )
    # Take the mean of the encoder's last hidden states
    return encoder_outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# %%
dp_path = "/content/C_codet5_code_Vdb"
import os
import chromadb
os.makedirs(dp_path , exist_ok= True)
client = chromadb.PersistentClient(path=dp_path)
collection = client.get_or_create_collection(name="C_codet5_code_collection")

for i in range (len(codes)):
    embedding = generate_embedding(codes[i])
    print(f"Code {i}: Embedding size = {embedding.shape}")
    collection.add(
        documents=[codes[i]],
        metadatas=[{"index": str(ids[i])}],
        ids=[str(ids[i])],
        embeddings=[embedding.tolist()]
    )

print(collection.get()['documents'])
# Out:
# Code 0: Embedding size = (768,)
# Code 1: Embedding size = (768,)
# Code 2: Embedding size = (768,)
# Code 3: Embedding size = (768,)
# Code 4: Embedding size = (768,)
# Code 5: Embedding size = (768,)
# Code 6: Embedding size = (768,)
# Code 7: Embedding size = (768,)
# Code 8: Embedding size = (768,)
# Code 9: Embedding size = (768,)
# Code 10: Embedding size = (768,)
# Code 11: Embedding size = (768,)
# Code 12: Embedding size = (768,)
# Code 13: Embedding size = (768,)
# Code 14: Embedding size = (768,)
# Code 15: Embedding size = (768,)
# Code 16: Embedding size = (768,)
# Code 17: Embedding size = (768,)
# Code 18: Embedding size = (768,)
# Code 19: Embedding size = (768,)
# Code 20: Embedding size = (768,)
# Code 21: Embedding size = (768,)
# Code 22: Embedding size = (768,)
# Code 23: Embedding size = (768,)
# Code 24: Embedding size = (768,)
# Code 25: Embedding size = (768,)
# Code 26: Embedding size = (768,)
# Code 27: Embedding size = (768,)
# Code 28: Embedding size = (768,)
# Code 29: Embedding size = (768,)
# Code 30: Embedding size = (768,)
# Code 31: Embedding size = (768,)
# Code 32: Embedding size = (768,)
# Code 33: Embedding size = (768,)
# Code 34: Embedding size = (768,)
# Code 35: Embedding size = (768,)
# Code 36: Embedding size = (768,)
# Code 37: Embedding size = (768,)
# Code 38: Embedding size = (768,)
# Code 39: Embedding size = (768,)
# Code 40: Embedding size = (768,)
# Code 41: Embedding size = (768,)
# Code 42: Embedding size = (768,)
# Code 43: Embedding size = (768,)
# Code 44: Embedding size = (768,)
# Code 45: Embedding size = (768,)
# Code 46: Embedding size = (768,)
# Code 47: Embedding size = (768,)
# Code 48: Embedding size = (768,)
# Code 49: Embedding size = (768,)
# Code 50: Embedding size = (768,)
# Code 51: Embedding size = (768,)
# Code 52: Embedding size = (768,)
# Code 53: Embedding size = (768,)
# Code 54: Embedding size = (768,)
# Code 55: Embedding size = (768,)
# Code 56: Embedding size = (768,)
# Code 57: Embedding size = (768,)
# Code 58: Embedding size = (768,)
# Code 59: Embedding size = (768,)
# Code 60: Embedding size = (768,)
# Code 61: Embedding size = (768,)
# Code 62: Embedding size = (768,)
# Code 63: Embedding size = (768,)
# Code 64: Embedding size = (768,)
# Code 65: Embedding size = (768,)
# Code 66: Embedding size = (768,)
# Code 67: Embedding size = (768,)
# Code 68: Embedding size = (768,)
# Code 69: Embedding size = (768,)
# Code 70: Embedding size = (768,)
# Code 71: Embedding size = (768,)
# Code 72: Embedding size = (768,)
# Code 73: Embedding size = (768,)
# Code 74: Embedding size = (768,)
# Code 75: Embedding size = (768,)
# Code 76: Embedding size = (768,)
# Code 77: Embedding size = (768,)
# Code 78: Embedding size = (768,)
# Code 79: Embedding size = (768,)
# Code 80: Embedding size = (768,)
# Code 81: Embedding size = (768,)
# Code 82: Embedding size = (768,)
# Code 83: Embedding size = (768,)
# Code 84: Embedding size = (768,)
# Code 85: Embedding size = (768,)
# Code 86: Embedding size = (768,)
# Code 87: Embedding size = (768,)
# Code 88: Embedding size = (768,)
# Code 89: Embedding size = (768,)
# Code 90: Embedding size = (768,)
# Code 91: Embedding size = (768,)
# Code 92: Embedding size = (768,)
# Code 93: Embedding size = (768,)
# Code 94: Embedding size = (768,)
# Code 95: Embedding size = (768,)
# Code 96: Embedding size = (768,)
# Code 97: Embedding size = (768,)
# Code 98: Embedding size = (768,)
# Code 99: Embedding size = (768,)
# Code 100: Embedding size = (768,)
# Code 101: Embedding size = (768,)
# Code 102: Embedding size = (768,)
# Code 103: Embedding size = (768,)
# Code 104: Embedding size = (768,)
# Code 105: Embedding size = (768,)
# Code 106: Embedding size = (768,)
# Code 107: Embedding size = (768,)
# Code 108: Embedding size = (768,)
# Code 109: Embedding size = (768,)
# Code 110: Embedding size = (768,)
# Code 111: Embedding size = (768,)
# Code 112: Embedding size = (768,)
# Code 113: Embedding size = (768,)
# Code 114: Embedding size = (768,)
# Code 115: Embedding size = (768,)
# Code 116: Embedding size = (768,)
# Code 117: Embedding size = (768,)
# Code 118: Embedding size = (768,)
# Code 119: Embedding size = (768,)
# Code 120: Embedding size = (768,)
# Code 121: Embedding size = (768,)
# Code 122: Embedding size = (768,)
# Code 123: Embedding size = (768,)
# Code 124: Embedding size = (768,)
# Code 125: Embedding size = (768,)
# Code 126: Embedding size = (768,)
# Code 127: Embedding size = (768,)
# Code 128: Embedding size = (768,)
# Code 129: Embedding size = (768,)
# Code 130: Embedding size = (768,)
# Code 131: Embedding size = (768,)
# Code 132: Embedding size = (768,)
# Code 133: Embedding size = (768,)
# Code 134: Embedding size = (768,)
# Code 135: Embedding size = (768,)
# Code 136: Embedding size = (768,)
# Code 137: Embedding size = (768,)
# Code 138: Embedding size = (768,)
# Code 139: Embedding size = (768,)
# Code 140: Embedding size = (768,)
# Code 141: Embedding size = (768,)
# Code 142: Embedding size = (768,)
# Code 143: Embedding size = (768,)
# Code 144: Embedding size = (768,)
# Code 145: Embedding size = (768,)
# Code 146: Embedding size = (768,)
# Code 147: Embedding size = (768,)
# Code 148: Embedding size = (768,)
# Code 149: Embedding size = (768,)
# Code 150: Embedding size = (768,)
# Code 151: Embedding size = (768,)
# Code 152: Embedding size = (768,)
# Code 153: Embedding size = (768,)
# Code 154: Embedding size = (768,)
# Code 155: Embedding size = (768,)
# Code 156: Embedding size = (768,)
# Code 157: Embedding size = (768,)
# Code 158: Embedding size = (768,)
# Code 159: Embedding size = (768,)
# Code 160: Embedding size = (768,)
# Code 161: Embedding size = (768,)
# Code 162: Embedding size = (768,)
# Code 163: Embedding size = (768,)
# Code 164: Embedding size = (768,)
# Code 165: Embedding size = (768,)
# Code 166: Embedding size = (768,)
# Code 167: Embedding size = (768,)
# Code 168: Embedding size = (768,)
# Code 169: Embedding size = (768,)
# Code 170: Embedding size = (768,)
# Code 171: Embedding size = (768,)
# Code 172: Embedding size = (768,)
# Code 173: Embedding size = (768,)
# Code 174: Embedding size = (768,)
# Code 175: Embedding size = (768,)
# Code 176: Embedding size = (768,)
# Code 177: Embedding size = (768,)
# Code 178: Embedding size = (768,)
# Code 179: Embedding size = (768,)
# Code 180: Embedding size = (768,)
# Code 181: Embedding size = (768,)
# Code 182: Embedding size = (768,)
# Code 183: Embedding size = (768,)
# Code 184: Embedding size = (768,)
# Code 185: Embedding size = (768,)
# Code 186: Embedding size = (768,)
# Code 187: Embedding size = (768,)
# Code 188: Embedding size = (768,)
# Code 189: Embedding size = (768,)
# Code 190: Embedding size = (768,)
# Code 191: Embedding size = (768,)
# Code 192: Embedding size = (768,)
# Code 193: Embedding size = (768,)
# Code 194: Embedding size = (768,)
# Code 195: Embedding size = (768,)
# Code 196: Embedding size = (768,)
# Code 197: Embedding size = (768,)
# Code 198: Embedding size = (768,)
# Code 199: Embedding size = (768,)
# Code 200: Embedding size = (768,)
# Code 201: Embedding size = (768,)
# Code 202: Embedding size = (768,)
# Code 203: Embedding size = (768,)
# Code 204: Embedding size = (768,)
# Code 205: Embedding size = (768,)
# Code 206: Embedding size = (768,)
# Code 207: Embedding size = (768,)
# Code 208: Embedding size = (768,)
# Code 209: Embedding size = (768,)
# Code 210: Embedding size = (768,)
# Code 211: Embedding size = (768,)
# Code 212: Embedding size = (768,)
# Code 213: Embedding size = (768,)
# Code 214: Embedding size = (768,)
# Code 215: Embedding size = (768,)
# Code 216: Embedding size = (768,)
# Code 217: Embedding size = (768,)
# Code 218: Embedding size = (768,)
# Code 219: Embedding size = (768,)
# Code 220: Embedding size = (768,)
# Code 221: Embedding size = (768,)
# Code 222: Embedding size = (768,)
# Code 223: Embedding size = (768,)
# Code 224: Embedding size = (768,)
# Code 225: Embedding size = (768,)
# Code 226: Embedding size = (768,)
# Code 227: Embedding size = (768,)
# Code 228: Embedding size = (768,)
# Code 229: Embedding size = (768,)
# Code 230: Embedding size = (768,)
# Code 231: Embedding size = (768,)
# Code 232: Embedding size = (768,)
# Code 233: Embedding size = (768,)
# Code 234: Embedding size = (768,)
# Code 235: Embedding size = (768,)
# Code 236: Embedding size = (768,)
# Code 237: Embedding size = (768,)
# Code 238: Embedding size = (768,)
# Code 239: Embedding size = (768,)
# Code 240: Embedding size = (768,)
# Code 241: Embedding size = (768,)
# Code 242: Embedding size = (768,)
# Code 243: Embedding size = (768,)
# Code 244: Embedding size = (768,)
# Code 245: Embedding size = (768,)
# Code 246: Embedding size = (768,)
# Code 247: Embedding size = (768,)
# Code 248: Embedding size = (768,)
# Code 249: Embedding size = (768,)
# Code 250: Embedding size = (768,)
# Code 251: Embedding size = (768,)
# Code 252: Embedding size = (768,)
# Code 253: Embedding size = (768,)
# Code 254: Embedding size = (768,)
# Code 255: Embedding size = (768,)
# Code 256: Embedding size = (768,)
# Code 257: Embedding size = (768,)
# Code 258: Embedding size = (768,)
# Code 259: Embedding size = (768,)
# Code 260: Embedding size = (768,)
# Code 261: Embedding size = (768,)
# Code 262: Embedding size = (768,)
# Code 263: Embedding size = (768,)
# Code 264: Embedding size = (768,)
# Code 265: Embedding size = (768,)
# Code 266: Embedding size = (768,)
# Code 267: Embedding size = (768,)
# Code 268: Embedding size = (768,)
# Code 269: Embedding size = (768,)
# Code 270: Embedding size = (768,)
# Code 271: Embedding size = (768,)
# Code 272: Embedding size = (768,)
# Code 273: Embedding size = (768,)
# Code 274: Embedding size = (768,)
# Code 275: Embedding size = (768,)
# Code 276: Embedding size = (768,)
# Code 277: Embedding size = (768,)
# Code 278: Embedding size = (768,)
# Code 279: Embedding size = (768,)
# Code 280: Embedding size = (768,)
# Code 281: Embedding size = (768,)
# Code 282: Embedding size = (768,)
# Code 283: Embedding size = (768,)
# Code 284: Embedding size = (768,)
# Code 285: Embedding size = (768,)
# Code 286: Embedding size = (768,)
# Code 287: Embedding size = (768,)
# Code 288: Embedding size = (768,)
# Code 289: Embedding size = (768,)
# Code 290: Embedding size = (768,)
# Code 291: Embedding size = (768,)
# Code 292: Embedding size = (768,)
# Code 293: Embedding size = (768,)
# Code 294: Embedding size = (768,)
# Code 295: Embedding size = (768,)
# Code 296: Embedding size = (768,)
# Code 297: Embedding size = (768,)
# Code 298: Embedding size = (768,)
# Code 299: Embedding size = (768,)
# Code 300: Embedding size = (768,)
# Code 301: Embedding size = (768,)
# Code 302: Embedding size = (768,)
# Code 303: Embedding size = (768,)
# Code 304: Embedding size = (768,)
# Code 305: Embedding size = (768,)
# Code 306: Embedding size = (768,)
# Code 307: Embedding size = (768,)
# Code 308: Embedding size = (768,)
# Code 309: Embedding size = (768,)
# Code 310: Embedding size = (768,)
# Code 311: Embedding size = (768,)
# Code 312: Embedding size = (768,)
# Code 313: Embedding size = (768,)
# Code 314: Embedding size = (768,)
# Code 315: Embedding size = (768,)
# Code 316: Embedding size = (768,)
# Code 317: Embedding size = (768,)
# Code 318: Embedding size = (768,)
# Code 319: Embedding size = (768,)
# Code 320: Embedding size = (768,)
# Code 321: Embedding size = (768,)
# Code 322: Embedding size = (768,)
# Code 323: Embedding size = (768,)
# Code 324: Embedding size = (768,)
# Code 325: Embedding size = (768,)
# Code 326: Embedding size = (768,)
# Code 327: Embedding size = (768,)
# Code 328: Embedding size = (768,)
# Code 329: Embedding size = (768,)
# Code 330: Embedding size = (768,)
# Code 331: Embedding size = (768,)
# Code 332: Embedding size = (768,)
# Code 333: Embedding size = (768,)
# Code 334: Embedding size = (768,)
# Code 335: Embedding size = (768,)
# Code 336: Embedding size = (768,)
# Code 337: Embedding size = (768,)
# Code 338: Embedding size = (768,)
# Code 339: Embedding size = (768,)
# Code 340: Embedding size = (768,)
# Code 341: Embedding size = (768,)
# Code 342: Embedding size = (768,)
# Code 343: Embedding size = (768,)
# Code 344: Embedding size = (768,)
# Code 345: Embedding size = (768,)
# Code 346: Embedding size = (768,)
# Code 347: Embedding size = (768,)
# Code 348: Embedding size = (768,)
# Code 349: Embedding size = (768,)
# Code 350: Embedding size = (768,)
# Code 351: Embedding size = (768,)
# Code 352: Embedding size = (768,)
# Code 353: Embedding size = (768,)
# Code 354: Embedding size = (768,)
# Code 355: Embedding size = (768,)
# Code 356: Embedding size = (768,)
# Code 357: Embedding size = (768,)
# Code 358: Embedding size = (768,)
# Code 359: Embedding size = (768,)
# Code 360: Embedding size = (768,)
# Code 361: Embedding size = (768,)
# Code 362: Embedding size = (768,)
# Code 363: Embedding size = (768,)
# Code 364: Embedding size = (768,)
# Code 365: Embedding size = (768,)
# Code 366: Embedding size = (768,)
# Code 367: Embedding size = (768,)
# Code 368: Embedding size = (768,)
# Code 369: Embedding size = (768,)
# Code 370: Embedding size = (768,)
# Code 371: Embedding size = (768,)
# Code 372: Embedding size = (768,)
# Code 373: Embedding size = (768,)
# Code 374: Embedding size = (768,)
# Code 375: Embedding size = (768,)
# Code 376: Embedding size = (768,)
# Code 377: Embedding size = (768,)
# Code 378: Embedding size = (768,)
# Code 379: Embedding size = (768,)
# Code 380: Embedding size = (768,)
# Code 381: Embedding size = (768,)
# Code 382: Embedding size = (768,)
# Code 383: Embedding size = (768,)
# Code 384: Embedding size = (768,)
# Code 385: Embedding size = (768,)
# Code 386: Embedding size = (768,)
# Code 387: Embedding size = (768,)
# Code 388: Embedding size = (768,)
# Code 389: Embedding size = (768,)
# Code 390: Embedding size = (768,)
# Code 391: Embedding size = (768,)
# Code 392: Embedding size = (768,)
# Code 393: Embedding size = (768,)
# Code 394: Embedding size = (768,)
# Code 395: Embedding size = (768,)
# Code 396: Embedding size = (768,)
# Code 397: Embedding size = (768,)
# Code 398: Embedding size = (768,)
# Code 399: Embedding size = (768,)
# Code 400: Embedding size = (768,)
# Code 401: Embedding size = (768,)
# Code 402: Embedding size = (768,)
# Code 403: Embedding size = (768,)
# Code 404: Embedding size = (768,)
# Code 405: Embedding size = (768,)
# Code 406: Embedding size = (768,)
# Code 407: Embedding size = (768,)
# Code 408: Embedding size = (768,)
# Code 409: Embedding size = (768,)
# Code 410: Embedding size = (768,)
# Code 411: Embedding size = (768,)
# Code 412: Embedding size = (768,)
# Code 413: Embedding size = (768,)
# Code 414: Embedding size = (768,)
# Code 415: Embedding size = (768,)
# Code 416: Embedding size = (768,)
# Code 417: Embedding size = (768,)
# Code 418: Embedding size = (768,)
# Code 419: Embedding size = (768,)
# Code 420: Embedding size = (768,)
# Code 421: Embedding size = (768,)
# Code 422: Embedding size = (768,)
# Code 423: Embedding size = (768,)
# Code 424: Embedding size = (768,)
# Code 425: Embedding size = (768,)
# Code 426: Embedding size = (768,)
# Code 427: Embedding size = (768,)
# Code 428: Embedding size = (768,)
# Code 429: Embedding size = (768,)
# Code 430: Embedding size = (768,)
# Code 431: Embedding size = (768,)
# Code 432: Embedding size = (768,)
# Code 433: Embedding size = (768,)
# Code 434: Embedding size = (768,)
# Code 435: Embedding size = (768,)
# Code 436: Embedding size = (768,)
# Code 437: Embedding size = (768,)
# Code 438: Embedding size = (768,)
# Code 439: Embedding size = (768,)
# Code 440: Embedding size = (768,)
# Code 441: Embedding size = (768,)
# Code 442: Embedding size = (768,)
# Code 443: Embedding size = (768,)
# Code 444: Embedding size = (768,)
# Code 445: Embedding size = (768,)
# Code 446: Embedding size = (768,)
# Code 447: Embedding size = (768,)
# Code 448: Embedding size = (768,)
# Code 449: Embedding size = (768,)
# Code 450: Embedding size = (768,)
# Code 451: Embedding size = (768,)
# Code 452: Embedding size = (768,)
# Code 453: Embedding size = (768,)
# Code 454: Embedding size = (768,)
# Code 455: Embedding size = (768,)
# Code 456: Embedding size = (768,)
# Code 457: Embedding size = (768,)
# Code 458: Embedding size = (768,)
# Code 459: Embedding size = (768,)
# Code 460: Embedding size = (768,)
# Code 461: Embedding size = (768,)
# Code 462: Embedding size = (768,)
# Code 463: Embedding size = (768,)
# Code 464: Embedding size = (768,)
# Code 465: Embedding size = (768,)
# Code 466: Embedding size = (768,)
# Code 467: Embedding size = (768,)
# Code 468: Embedding size = (768,)
# Code 469: Embedding size = (768,)
# Code 470: Embedding size = (768,)
# Code 471: Embedding size = (768,)
# Code 472: Embedding size = (768,)
# Code 473: Embedding size = (768,)
# Code 474: Embedding size = (768,)
# Code 475: Embedding size = (768,)
# Code 476: Embedding size = (768,)
# Code 477: Embedding size = (768,)
# Code 478: Embedding size = (768,)
# Code 479: Embedding size = (768,)
# Code 480: Embedding size = (768,)
# Code 481: Embedding size = (768,)
# Code 482: Embedding size = (768,)
# Code 483: Embedding size = (768,)
# Code 484: Embedding size = (768,)
# Code 485: Embedding size = (768,)
# Code 486: Embedding size = (768,)
# Code 487: Embedding size = (768,)
# Code 488: Embedding size = (768,)
# Code 489: Embedding size = (768,)
# Code 490: Embedding size = (768,)
# Code 491: Embedding size = (768,)
# Code 492: Embedding size = (768,)
# Code 493: Embedding size = (768,)
# Code 494: Embedding size = (768,)
# Code 495: Embedding size = (768,)
# Code 496: Embedding size = (768,)
# Code 497: Embedding size = (768,)
# Code 498: Embedding size = (768,)
# Code 499: Embedding size = (768,)
# Code 500: Embedding size = (768,)
# Code 501: Embedding size = (768,)
# Code 502: Embedding size = (768,)
# Code 503: Embedding size = (768,)
# Code 504: Embedding size = (768,)
# Code 505: Embedding size = (768,)
# Code 506: Embedding size = (768,)
# Code 507: Embedding size = (768,)
# Code 508: Embedding size = (768,)
# Code 509: Embedding size = (768,)
# Code 510: Embedding size = (768,)
# Code 511: Embedding size = (768,)
# Code 512: Embedding size = (768,)
# Code 513: Embedding size = (768,)
# Code 514: Embedding size = (768,)
# Code 515: Embedding size = (768,)
# Code 516: Embedding size = (768,)
# Code 517: Embedding size = (768,)
# Code 518: Embedding size = (768,)
# Code 519: Embedding size = (768,)
# Code 520: Embedding size = (768,)
# Code 521: Embedding size = (768,)
# Code 522: Embedding size = (768,)
# Code 523: Embedding size = (768,)
# Code 524: Embedding size = (768,)
# Code 525: Embedding size = (768,)
# Code 526: Embedding size = (768,)
# Code 527: Embedding size = (768,)
# Code 528: Embedding size = (768,)
# Code 529: Embedding size = (768,)
# Code 530: Embedding size = (768,)
# Code 531: Embedding size = (768,)
# Code 532: Embedding size = (768,)
# Code 533: Embedding size = (768,)
# Code 534: Embedding size = (768,)
# Code 535: Embedding size = (768,)
# Code 536: Embedding size = (768,)
# Code 537: Embedding size = (768,)
# Code 538: Embedding size = (768,)
# Code 539: Embedding size = (768,)
# Code 540: Embedding size = (768,)
# Code 541: Embedding size = (768,)
# Code 542: Embedding size = (768,)
# Code 543: Embedding size = (768,)
# Code 544: Embedding size = (768,)
# Code 545: Embedding size = (768,)
# Code 546: Embedding size = (768,)
# Code 547: Embedding size = (768,)
# Code 548: Embedding size = (768,)
# Code 549: Embedding size = (768,)
# Code 550: Embedding size = (768,)
# Code 551: Embedding size = (768,)
# Code 552: Embedding size = (768,)
# Code 553: Embedding size = (768,)
# Code 554: Embedding size = (768,)
# Code 555: Embedding size = (768,)
# Code 556: Embedding size = (768,)
# Code 557: Embedding size = (768,)
# Code 558: Embedding size = (768,)
# Code 559: Embedding size = (768,)
# Code 560: Embedding size = (768,)
# Code 561: Embedding size = (768,)
# Code 562: Embedding size = (768,)
# Code 563: Embedding size = (768,)
# Code 564: Embedding size = (768,)
# Code 565: Embedding size = (768,)
# Code 566: Embedding size = (768,)
# Code 567: Embedding size = (768,)
# Code 568: Embedding size = (768,)
# Code 569: Embedding size = (768,)
# Code 570: Embedding size = (768,)
# Code 571: Embedding size = (768,)
# Code 572: Embedding size = (768,)
# Code 573: Embedding size = (768,)
# Code 574: Embedding size = (768,)
# Code 575: Embedding size = (768,)
# Code 576: Embedding size = (768,)
# Code 577: Embedding size = (768,)
# Code 578: Embedding size = (768,)
# Code 579: Embedding size = (768,)
# Code 580: Embedding size = (768,)
# Code 581: Embedding size = (768,)
# Code 582: Embedding size = (768,)
# Code 583: Embedding size = (768,)
# Code 584: Embedding size = (768,)
# Code 585: Embedding size = (768,)
# Code 586: Embedding size = (768,)
# Code 587: Embedding size = (768,)
# Code 588: Embedding size = (768,)
# Code 589: Embedding size = (768,)
# Code 590: Embedding size = (768,)
# Code 591: Embedding size = (768,)
# Code 592: Embedding size = (768,)
# Code 593: Embedding size = (768,)
# Code 594: Embedding size = (768,)
# Code 595: Embedding size = (768,)
# Code 596: Embedding size = (768,)
# Code 597: Embedding size = (768,)
# Code 598: Embedding size = (768,)
# Code 599: Embedding size = (768,)
# Code 600: Embedding size = (768,)
# Code 601: Embedding size = (768,)
# Code 602: Embedding size = (768,)
# Code 603: Embedding size = (768,)
# Code 604: Embedding size = (768,)
# Code 605: Embedding size = (768,)
# Code 606: Embedding size = (768,)
# Code 607: Embedding size = (768,)
# Code 608: Embedding size = (768,)
# Code 609: Embedding size = (768,)
# Code 610: Embedding size = (768,)
# Code 611: Embedding size = (768,)
# Code 612: Embedding size = (768,)
# Code 613: Embedding size = (768,)
# Code 614: Embedding size = (768,)
# Code 615: Embedding size = (768,)
# Code 616: Embedding size = (768,)
# Code 617: Embedding size = (768,)
# Code 618: Embedding size = (768,)
# Code 619: Embedding size = (768,)
# Code 620: Embedding size = (768,)
# Code 621: Embedding size = (768,)
# Code 622: Embedding size = (768,)
# Code 623: Embedding size = (768,)
# Code 624: Embedding size = (768,)
# Code 625: Embedding size = (768,)
# Code 626: Embedding size = (768,)
# Code 627: Embedding size = (768,)
# Code 628: Embedding size = (768,)
# Code 629: Embedding size = (768,)
# Code 630: Embedding size = (768,)
# Code 631: Embedding size = (768,)
# Code 632: Embedding size = (768,)
# Code 633: Embedding size = (768,)
# Code 634: Embedding size = (768,)
# Code 635: Embedding size = (768,)
# Code 636: Embedding size = (768,)
# Code 637: Embedding size = (768,)
# Code 638: Embedding size = (768,)
# Code 639: Embedding size = (768,)
# Code 640: Embedding size = (768,)
# Code 641: Embedding size = (768,)
# Code 642: Embedding size = (768,)
# Code 643: Embedding size = (768,)
# Code 644: Embedding size = (768,)
# Code 645: Embedding size = (768,)
# Code 646: Embedding size = (768,)
# Code 647: Embedding size = (768,)
# Code 648: Embedding size = (768,)
# Code 649: Embedding size = (768,)
# Code 650: Embedding size = (768,)
# Code 651: Embedding size = (768,)
# Code 652: Embedding size = (768,)
# Code 653: Embedding size = (768,)
# Code 654: Embedding size = (768,)
# Code 655: Embedding size = (768,)
# Code 656: Embedding size = (768,)
# Code 657: Embedding size = (768,)
# Code 658: Embedding size = (768,)
# Code 659: Embedding size = (768,)
# Code 660: Embedding size = (768,)
# Code 661: Embedding size = (768,)
# Code 662: Embedding size = (768,)
# Code 663: Embedding size = (768,)
# Code 664: Embedding size = (768,)
# Code 665: Embedding size = (768,)
# Code 666: Embedding size = (768,)
# Code 667: Embedding size = (768,)
# Code 668: Embedding size = (768,)
# Code 669: Embedding size = (768,)
# Code 670: Embedding size = (768,)
# Code 671: Embedding size = (768,)
# Code 672: Embedding size = (768,)
# Code 673: Embedding size = (768,)
# Code 674: Embedding size = (768,)
# Code 675: Embedding size = (768,)
# Code 676: Embedding size = (768,)
# Code 677: Embedding size = (768,)
# Code 678: Embedding size = (768,)
# Code 679: Embedding size = (768,)
# Code 680: Embedding size = (768,)
# Code 681: Embedding size = (768,)
# Code 682: Embedding size = (768,)
# Code 683: Embedding size = (768,)
# Code 684: Embedding size = (768,)
# Code 685: Embedding size = (768,)
# Code 686: Embedding size = (768,)
# Code 687: Embedding size = (768,)
# Code 688: Embedding size = (768,)
# Code 689: Embedding size = (768,)
# Code 690: Embedding size = (768,)
# Code 691: Embedding size = (768,)
# Code 692: Embedding size = (768,)
# Code 693: Embedding size = (768,)
# Code 694: Embedding size = (768,)
# Code 695: Embedding size = (768,)
# Code 696: Embedding size = (768,)
# Code 697: Embedding size = (768,)
# Code 698: Embedding size = (768,)
# Code 699: Embedding size = (768,)
# Code 700: Embedding size = (768,)
# Code 701: Embedding size = (768,)
# Code 702: Embedding size = (768,)
# Code 703: Embedding size = (768,)
# Code 704: Embedding size = (768,)
# Code 705: Embedding size = (768,)
# Code 706: Embedding size = (768,)
# Code 707: Embedding size = (768,)
# Code 708: Embedding size = (768,)
# Code 709: Embedding size = (768,)
# Code 710: Embedding size = (768,)
# Code 711: Embedding size = (768,)
# Code 712: Embedding size = (768,)
# Code 713: Embedding size = (768,)
# Code 714: Embedding size = (768,)
# Code 715: Embedding size = (768,)
# Code 716: Embedding size = (768,)
# Code 717: Embedding size = (768,)
# Code 718: Embedding size = (768,)
# Code 719: Embedding size = (768,)
# Code 720: Embedding size = (768,)
# Code 721: Embedding size = (768,)
# Code 722: Embedding size = (768,)
# Code 723: Embedding size = (768,)
# Code 724: Embedding size = (768,)
# Code 725: Embedding size = (768,)
# Code 726: Embedding size = (768,)
# Code 727: Embedding size = (768,)
# Code 728: Embedding size = (768,)
# Code 729: Embedding size = (768,)
# Code 730: Embedding size = (768,)
# Code 731: Embedding size = (768,)
# Code 732: Embedding size = (768,)
# Code 733: Embedding size = (768,)
# Code 734: Embedding size = (768,)
# Code 735: Embedding size = (768,)
# Code 736: Embedding size = (768,)
# Code 737: Embedding size = (768,)
# Code 738: Embedding size = (768,)
# Code 739: Embedding size = (768,)
# Code 740: Embedding size = (768,)
# Code 741: Embedding size = (768,)
# Code 742: Embedding size = (768,)
# Code 743: Embedding size = (768,)
# Code 744: Embedding size = (768,)
# Code 745: Embedding size = (768,)
# Code 746: Embedding size = (768,)
# Code 747: Embedding size = (768,)
# Code 748: Embedding size = (768,)
# Code 749: Embedding size = (768,)
# Code 750: Embedding size = (768,)
# Code 751: Embedding size = (768,)
# Code 752: Embedding size = (768,)
# Code 753: Embedding size = (768,)
# Code 754: Embedding size = (768,)
# Code 755: Embedding size = (768,)
# Code 756: Embedding size = (768,)
# Code 757: Embedding size = (768,)
# Code 758: Embedding size = (768,)
# Code 759: Embedding size = (768,)
# Code 760: Embedding size = (768,)
# Code 761: Embedding size = (768,)
# Code 762: Embedding size = (768,)
# Code 763: Embedding size = (768,)
# Code 764: Embedding size = (768,)
# Code 765: Embedding size = (768,)
# Code 766: Embedding size = (768,)
# Code 767: Embedding size = (768,)
# Code 768: Embedding size = (768,)
# Code 769: Embedding size = (768,)
# Code 770: Embedding size = (768,)
# Code 771: Embedding size = (768,)
# Code 772: Embedding size = (768,)
# Code 773: Embedding size = (768,)
# Code 774: Embedding size = (768,)
# Code 775: Embedding size = (768,)
# Code 776: Embedding size = (768,)
# Code 777: Embedding size = (768,)
# Code 778: Embedding size = (768,)
# Code 779: Embedding size = (768,)
# Code 780: Embedding size = (768,)
# Code 781: Embedding size = (768,)
# Code 782: Embedding size = (768,)
# Code 783: Embedding size = (768,)
# Code 784: Embedding size = (768,)
# Code 785: Embedding size = (768,)
# Code 786: Embedding size = (768,)
# Code 787: Embedding size = (768,)
# Code 788: Embedding size = (768,)
# Code 789: Embedding size = (768,)
# Code 790: Embedding size = (768,)
# Code 791: Embedding size = (768,)
# Code 792: Embedding size = (768,)
# Code 793: Embedding size = (768,)
# Code 794: Embedding size = (768,)
# Code 795: Embedding size = (768,)
# Code 796: Embedding size = (768,)
# Code 797: Embedding size = (768,)
# Code 798: Embedding size = (768,)
# Code 799: Embedding size = (768,)
# Code 800: Embedding size = (768,)
# Code 801: Embedding size = (768,)
# Code 802: Embedding size = (768,)
# Code 803: Embedding size = (768,)
# Code 804: Embedding size = (768,)
# Code 805: Embedding size = (768,)
# Code 806: Embedding size = (768,)
# Code 807: Embedding size = (768,)
# Code 808: Embedding size = (768,)
# Code 809: Embedding size = (768,)
# Code 810: Embedding size = (768,)
# Code 811: Embedding size = (768,)
# Code 812: Embedding size = (768,)
# Code 813: Embedding size = (768,)
# Code 814: Embedding size = (768,)
# Code 815: Embedding size = (768,)
# Code 816: Embedding size = (768,)
# Code 817: Embedding size = (768,)
# Code 818: Embedding size = (768,)
# Code 819: Embedding size = (768,)
# Code 820: Embedding size = (768,)
# Code 821: Embedding size = (768,)
# Code 822: Embedding size = (768,)
# Code 823: Embedding size = (768,)
# Code 824: Embedding size = (768,)
# Code 825: Embedding size = (768,)
# Code 826: Embedding size = (768,)
# Code 827: Embedding size = (768,)
# Code 828: Embedding size = (768,)
# Code 829: Embedding size = (768,)
# Code 830: Embedding size = (768,)
# Code 831: Embedding size = (768,)
# Code 832: Embedding size = (768,)
# Code 833: Embedding size = (768,)
# Code 834: Embedding size = (768,)
# Code 835: Embedding size = (768,)
# Code 836: Embedding size = (768,)
# Code 837: Embedding size = (768,)
# Code 838: Embedding size = (768,)
# Code 839: Embedding size = (768,)
# Code 840: Embedding size = (768,)
# Code 841: Embedding size = (768,)
# Code 842: Embedding size = (768,)
# Code 843: Embedding size = (768,)
# Code 844: Embedding size = (768,)
# Code 845: Embedding size = (768,)
# Code 846: Embedding size = (768,)
# Code 847: Embedding size = (768,)
# Code 848: Embedding size = (768,)
# Code 849: Embedding size = (768,)
# Code 850: Embedding size = (768,)
# Code 851: Embedding size = (768,)
# Code 852: Embedding size = (768,)
# Code 853: Embedding size = (768,)
# Code 854: Embedding size = (768,)
# Code 855: Embedding size = (768,)
# Code 856: Embedding size = (768,)
# Code 857: Embedding size = (768,)
# Code 858: Embedding size = (768,)
# Code 859: Embedding size = (768,)
# Code 860: Embedding size = (768,)
# Code 861: Embedding size = (768,)
# Code 862: Embedding size = (768,)
# Code 863: Embedding size = (768,)
# Code 864: Embedding size = (768,)
# Code 865: Embedding size = (768,)
# Code 866: Embedding size = (768,)
# Code 867: Embedding size = (768,)
# Code 868: Embedding size = (768,)
# Code 869: Embedding size = (768,)
# Code 870: Embedding size = (768,)
# Code 871: Embedding size = (768,)
# Code 872: Embedding size = (768,)
# Code 873: Embedding size = (768,)
# Code 874: Embedding size = (768,)
# Code 875: Embedding size = (768,)
# Code 876: Embedding size = (768,)
# Code 877: Embedding size = (768,)
# Code 878: Embedding size = (768,)
# Code 879: Embedding size = (768,)
# Code 880: Embedding size = (768,)
# Code 881: Embedding size = (768,)
# Code 882: Embedding size = (768,)
# Code 883: Embedding size = (768,)
# Code 884: Embedding size = (768,)
# Code 885: Embedding size = (768,)
# Code 886: Embedding size = (768,)
# Code 887: Embedding size = (768,)
# Code 888: Embedding size = (768,)
# Code 889: Embedding size = (768,)
# Code 890: Embedding size = (768,)
# Code 891: Embedding size = (768,)
# Code 892: Embedding size = (768,)
# Code 893: Embedding size = (768,)
# Code 894: Embedding size = (768,)
# Code 895: Embedding size = (768,)
# Code 896: Embedding size = (768,)
# Code 897: Embedding size = (768,)
# Code 898: Embedding size = (768,)
# Code 899: Embedding size = (768,)
# Code 900: Embedding size = (768,)
# Code 901: Embedding size = (768,)
# Code 902: Embedding size = (768,)
# Code 903: Embedding size = (768,)
# Code 904: Embedding size = (768,)
# Code 905: Embedding size = (768,)
# Code 906: Embedding size = (768,)
# Code 907: Embedding size = (768,)
# Code 908: Embedding size = (768,)
# Code 909: Embedding size = (768,)
# Code 910: Embedding size = (768,)
# Code 911: Embedding size = (768,)
# Code 912: Embedding size = (768,)
# Code 913: Embedding size = (768,)
# Code 914: Embedding size = (768,)
# Code 915: Embedding size = (768,)
# Code 916: Embedding size = (768,)
# Code 917: Embedding size = (768,)
# Code 918: Embedding size = (768,)
# Code 919: Embedding size = (768,)
# Code 920: Embedding size = (768,)
# Code 921: Embedding size = (768,)
# Code 922: Embedding size = (768,)
# Code 923: Embedding size = (768,)
# Code 924: Embedding size = (768,)
# Code 925: Embedding size = (768,)
# Code 926: Embedding size = (768,)
# Code 927: Embedding size = (768,)
# Code 928: Embedding size = (768,)
# Code 929: Embedding size = (768,)
# Code 930: Embedding size = (768,)
# Code 931: Embedding size = (768,)
# Code 932: Embedding size = (768,)
# Code 933: Embedding size = (768,)
# Code 934: Embedding size = (768,)
# Code 935: Embedding size = (768,)
# Code 936: Embedding size = (768,)
# Code 937: Embedding size = (768,)
# Code 938: Embedding size = (768,)
# Code 939: Embedding size = (768,)
# Code 940: Embedding size = (768,)
# Code 941: Embedding size = (768,)
# Code 942: Embedding size = (768,)
# Code 943: Embedding size = (768,)
# Code 944: Embedding size = (768,)
# Code 945: Embedding size = (768,)
# Code 946: Embedding size = (768,)
# Code 947: Embedding size = (768,)
# Code 948: Embedding size = (768,)
# Code 949: Embedding size = (768,)
# Code 950: Embedding size = (768,)
# Code 951: Embedding size = (768,)
# Code 952: Embedding size = (768,)
# Code 953: Embedding size = (768,)
# Code 954: Embedding size = (768,)
# Code 955: Embedding size = (768,)
# Code 956: Embedding size = (768,)
# Code 957: Embedding size = (768,)
# Code 958: Embedding size = (768,)
# Code 959: Embedding size = (768,)
# Code 960: Embedding size = (768,)
# Code 961: Embedding size = (768,)
# Code 962: Embedding size = (768,)
# Code 963: Embedding size = (768,)
# Code 964: Embedding size = (768,)
# Code 965: Embedding size = (768,)
# Code 966: Embedding size = (768,)
# Code 967: Embedding size = (768,)
# Code 968: Embedding size = (768,)
# Code 969: Embedding size = (768,)
# Code 970: Embedding size = (768,)
# Code 971: Embedding size = (768,)
# Code 972: Embedding size = (768,)
# Code 973: Embedding size = (768,)
# Code 974: Embedding size = (768,)
# Code 975: Embedding size = (768,)
# Code 976: Embedding size = (768,)
# Code 977: Embedding size = (768,)
# Code 978: Embedding size = (768,)
# Code 979: Embedding size = (768,)
# Code 980: Embedding size = (768,)
# Code 981: Embedding size = (768,)
# Code 982: Embedding size = (768,)
# Code 983: Embedding size = (768,)
# Code 984: Embedding size = (768,)
# Code 985: Embedding size = (768,)
# Code 986: Embedding size = (768,)
# Code 987: Embedding size = (768,)
# Code 988: Embedding size = (768,)
# Code 989: Embedding size = (768,)
# Code 990: Embedding size = (768,)
# Code 991: Embedding size = (768,)
# Code 992: Embedding size = (768,)
# Code 993: Embedding size = (768,)
# Code 994: Embedding size = (768,)
# Code 995: Embedding size = (768,)
# Code 996: Embedding size = (768,)
# Code 997: Embedding size = (768,)
# Code 998: Embedding size = (768,)
# Code 999: Embedding size = (768,)
# Code 1000: Embedding size = (768,)
# Code 1001: Embedding size = (768,)
# Code 1002: Embedding size = (768,)
# Code 1003: Embedding size = (768,)
# Code 1004: Embedding size = (768,)
# Code 1005: Embedding size = (768,)
# Code 1006: Embedding size = (768,)
# Code 1007: Embedding size = (768,)
# Code 1008: Embedding size = (768,)
# Code 1009: Embedding size = (768,)
# Code 1010: Embedding size = (768,)
# Code 1011: Embedding size = (768,)
# Code 1012: Embedding size = (768,)
# Code 1013: Embedding size = (768,)
# Code 1014: Embedding size = (768,)
# Code 1015: Embedding size = (768,)
# Code 1016: Embedding size = (768,)
# Code 1017: Embedding size = (768,)
# Code 1018: Embedding size = (768,)
# Code 1019: Embedding size = (768,)
# Code 1020: Embedding size = (768,)
# Code 1021: Embedding size = (768,)
# Code 1022: Embedding size = (768,)
# Code 1023: Embedding size = (768,)
# Code 1024: Embedding size = (768,)
# Code 1025: Embedding size = (768,)
# Code 1026: Embedding size = (768,)
# Code 1027: Embedding size = (768,)
# Code 1028: Embedding size = (768,)
# Code 1029: Embedding size = (768,)
# Code 1030: Embedding size = (768,)
# Code 1031: Embedding size = (768,)
# Code 1032: Embedding size = (768,)
# Code 1033: Embedding size = (768,)
# Code 1034: Embedding size = (768,)
# Code 1035: Embedding size = (768,)
# Code 1036: Embedding size = (768,)
# Code 1037: Embedding size = (768,)
# Code 1038: Embedding size = (768,)
# Code 1039: Embedding size = (768,)
# Code 1040: Embedding size = (768,)
# Code 1041: Embedding size = (768,)
# Code 1042: Embedding size = (768,)
# Code 1043: Embedding size = (768,)
# Code 1044: Embedding size = (768,)
# Code 1045: Embedding size = (768,)
# Code 1046: Embedding size = (768,)
# Code 1047: Embedding size = (768,)
# Code 1048: Embedding size = (768,)
# Code 1049: Embedding size = (768,)
# Code 1050: Embedding size = (768,)
# Code 1051: Embedding size = (768,)
# Code 1052: Embedding size = (768,)
# Code 1053: Embedding size = (768,)
# Code 1054: Embedding size = (768,)
# Code 1055: Embedding size = (768,)
# Code 1056: Embedding size = (768,)
# Code 1057: Embedding size = (768,)
# Code 1058: Embedding size = (768,)
# Code 1059: Embedding size = (768,)
# Code 1060: Embedding size = (768,)
# Code 1061: Embedding size = (768,)
# Code 1062: Embedding size = (768,)
# Code 1063: Embedding size = (768,)
# Code 1064: Embedding size = (768,)
# Code 1065: Embedding size = (768,)
# Code 1066: Embedding size = (768,)
# Code 1067: Embedding size = (768,)
# Code 1068: Embedding size = (768,)
# Code 1069: Embedding size = (768,)
# Code 1070: Embedding size = (768,)
# Code 1071: Embedding size = (768,)
# Code 1072: Embedding size = (768,)
# Code 1073: Embedding size = (768,)
# Code 1074: Embedding size = (768,)
# Code 1075: Embedding size = (768,)
# Code 1076: Embedding size = (768,)
# Code 1077: Embedding size = (768,)
# Code 1078: Embedding size = (768,)
# Code 1079: Embedding size = (768,)
# Code 1080: Embedding size = (768,)
# Code 1081: Embedding size = (768,)
# Code 1082: Embedding size = (768,)
# Code 1083: Embedding size = (768,)
# Code 1084: Embedding size = (768,)
# Code 1085: Embedding size = (768,)
# Code 1086: Embedding size = (768,)
# Code 1087: Embedding size = (768,)
# Code 1088: Embedding size = (768,)
# Code 1089: Embedding size = (768,)
# Code 1090: Embedding size = (768,)
# Code 1091: Embedding size = (768,)
# Code 1092: Embedding size = (768,)
# Code 1093: Embedding size = (768,)
# Code 1094: Embedding size = (768,)
# Code 1095: Embedding size = (768,)
# Code 1096: Embedding size = (768,)
# Code 1097: Embedding size = (768,)
# Code 1098: Embedding size = (768,)
# Code 1099: Embedding size = (768,)
# Code 1100: Embedding size = (768,)
# Code 1101: Embedding size = (768,)
# Code 1102: Embedding size = (768,)
# Code 1103: Embedding size = (768,)
# Code 1104: Embedding size = (768,)
# Code 1105: Embedding size = (768,)
# Code 1106: Embedding size = (768,)
# Code 1107: Embedding size = (768,)
# Code 1108: Embedding size = (768,)
# Code 1109: Embedding size = (768,)
# Code 1110: Embedding size = (768,)
# Code 1111: Embedding size = (768,)
# Code 1112: Embedding size = (768,)
# Code 1113: Embedding size = (768,)
# Code 1114: Embedding size = (768,)
# Code 1115: Embedding size = (768,)
# Code 1116: Embedding size = (768,)
# Code 1117: Embedding size = (768,)
# Code 1118: Embedding size = (768,)
# Code 1119: Embedding size = (768,)
# Code 1120: Embedding size = (768,)
# Code 1121: Embedding size = (768,)
# Code 1122: Embedding size = (768,)
# Code 1123: Embedding size = (768,)
# Code 1124: Embedding size = (768,)
# Code 1125: Embedding size = (768,)
# Code 1126: Embedding size = (768,)
# Code 1127: Embedding size = (768,)
# Code 1128: Embedding size = (768,)
# Code 1129: Embedding size = (768,)
# Code 1130: Embedding size = (768,)
# Code 1131: Embedding size = (768,)
# Code 1132: Embedding size = (768,)
# Code 1133: Embedding size = (768,)
# Code 1134: Embedding size = (768,)
# Code 1135: Embedding size = (768,)
# Code 1136: Embedding size = (768,)
# Code 1137: Embedding size = (768,)
# ['```cpp\n#include <iostream>\n#include <vector>\n#include <algorithm>\nusing namespace std;\n\nconst int R = 3;\nconst int C = 3;\n\npair<int, int> min_cost(vector<vector<int>>& cost, int m, int n) {\n    vector<vector<int>> tc(R, vector<int>(C, 0));\n    tc[0][0] = cost[0][0];\n    \n    for (int i = 1; i <= m; i++) \n        tc[i][0] = tc[i-1][0] + cost[i][0];\n        \n    for (int j = 1; j <= n; j++) \n        tc[0][j] = tc[0][j-1] + cost[0][j];\n        \n    for (int i = 1; i <= m; i++) {\n        for (int j = 1; j <= n; j++) {\n            tc[i][j] = min({tc[i-1][j-1], tc[i-1][j], tc[i][j-1]}) + cost[i][j];\n        }\n    }\n    \n    return {tc[m][n], 0}; // Replace 0 with an appropriate second value if needed\n}\n```', '```cpp\n#include <iostream>\n#include <tuple>\n#include <set>\n#include <vector>\n\nstd::tuple<std::set<int>> similar_elements(const std::vector<int>& test_tup1, const std::vector<int>& test_tup2) {\n    std::set<int> set1(test_tup1.begin(), test_tup1.end());\n    std::set<int> set2(test_tup2.begin(), test_tup2.end());\n    \n    std::set<int> res;\n    std::set_intersection(set1.begin(), set1.end(), set2.begin(), set2.end(), std::inserter(res, res.begin()));\n    \n    return std::make_tuple(res);\n}\n```', '```cpp\n#include <cmath>\n\nbool is_not_prime(int n) {\n    bool result = false;\n    for (int i = 2; i <= sqrt(n); ++i) {\n        if (n % i == 0) {\n            result = true;\n        }\n    }\n    return result;\n}\n```', '```cpp\n#include <vector>\n#include <queue>\n\nstd::vector<int> heap_queue_largest(const std::vector<int>& nums, int n) {\n    std::priority_queue<int> pq(nums.begin(), nums.end());\n    std::vector<int> largest_nums;\n    for (int i = 0; i < n && !pq.empty(); ++i) {\n        largest_nums.push_back(pq.top());\n        pq.pop();\n    }\n    return largest_nums;\n}\n```', '```cpp\n#include <vector>\n\nstd::pair<int, int> count_ways(int n) {\n    std::vector<int> A(n + 1, 0);\n    std::vector<int> B(n + 1, 0);\n    A[0] = 1;\n    A[1] = 0;\n    B[0] = 0;\n    B[1] = 1;\n    for (int i = 2; i <= n; ++i) {\n        A[i] = A[i - 2] + 2 * B[i - 1];\n        B[i] = A[i - 1] + B[i - 2];\n    }\n    return {A[n], B[n]};\n}\n```', '```cpp\nbool is_Power_Of_Two(int x) { \n    return x && !(x & (x - 1)); \n}\n\nbool differ_At_One_Bit_Pos(int a, int b) { \n    return is_Power_Of_Two(a ^ b); \n}\n```', '```cpp\n#include <iostream>\n#include <regex>\n#include <string>\n#include <vector>\n\nstd::vector<std::string> find_char_long(const std::string& text) {\n    std::regex word_regex(R"(\\b\\w{4,}\\b)");\n    std::sregex_iterator iter(text.begin(), text.end(), word_regex);\n    std::sregex_iterator end;\n\n    std::vector<std::string> results;\n    while (iter != end) {\n        results.push_back(iter->str());\n        ++iter;\n    }\n    return results;\n}\n```', '```cpp\n#include <vector>\n#include <algorithm>\n\nstd::pair<std::vector<int>, std::vector<int>> square_nums(const std::vector<int>& nums) {\n    std::vector<int> squared_nums(nums.size());\n    std::transform(nums.begin(), nums.end(), squared_nums.begin(), [](int x) { return x * x; });\n    return {squared_nums};\n}\n```', '```cpp\n#include <iostream>\n#include <string>\n\nint find_Rotations(const std::string& str) {\n    std::string tmp = str + str;\n    int n = str.length();\n    for (int i = 1; i <= n; ++i) {\n        std::string substring = tmp.substr(i, n);\n        if (str == substring) {\n            return i;\n        }\n    }\n    return n;\n}\n```', '```cpp\n#include <vector>\n#include <queue>\n#include <algorithm>\n\nstd::vector<int> small_nnum(const std::vector<int>& list1, int n) {\n    std::priority_queue<int, std::vector<int>, std::greater<int>> minHeap;\n    for (int num : list1) {\n        minHeap.push(num);\n    }\n    \n    std::vector<int> smallest;\n    for (int i = 0; i < n && !minHeap.empty(); ++i) {\n        smallest.push_back(minHeap.top());\n        minHeap.pop();\n    }\n    \n    return smallest;\n}\ ...

# %%
# !zip -r C_codet5_code_Vdb.zip /content/C_codet5_code_Vdb
from google.colab import files
files.download("C_codet5_code_Vdb.zip")
# Out:
#   adding: content/C_codet5_code_Vdb/ (stored 0%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/ (stored 0%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/index_metadata.pickle (deflated 48%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/link_lists.bin (deflated 88%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/header.bin (deflated 60%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/data_level0.bin (deflated 10%)
#   adding: content/C_codet5_code_Vdb/05447bd2-30cf-4c90-8fd8-a5e5603b1ca4/length.bin (deflated 82%)
#   adding: content/C_codet5_code_Vdb/chroma.sqlite3 (deflated 76%)
